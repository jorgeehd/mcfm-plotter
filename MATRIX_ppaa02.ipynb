# %%
import importlib
import dataset 
import compare 
import utils

importlib.reload(dataset)
importlib.reload(utils)
importlib.reload(compare)

# %%
filepath = "/Users/jorgehernandez/Desktop/MATRIX-hep-plots/run_elhueso/gnuplot/histograms"
